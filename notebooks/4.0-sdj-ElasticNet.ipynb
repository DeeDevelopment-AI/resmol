# %%
from IPython.display import Image
from IPython.display import display, HTML
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from fboost import outlier_iqr, DataPreparator, FeatureBoosterRegressor
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import OneHotEncoder

from sklearn.linear_model import LinearRegression, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score


import warnings
warnings.filterwarnings('ignore')

# Set a seed value
seed_value= 0
# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)
# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)
# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)

# %%
data = pd.read_csv('../data/raw/alldata.csv')
data.columns = ['familia','indice_fam','subposicion_1','subposicion_2','subposicion_3','subposicion_4', 'energia']
mask = (data[['subposicion_1','subposicion_2','subposicion_3','subposicion_4']] == 0).sum(axis=1) > 1
lista_train = data.loc[mask,['subposicion_1','subposicion_2','subposicion_3','subposicion_4','energia']]
lista_test = data.loc[~mask,['subposicion_1','subposicion_2','subposicion_3','subposicion_4','energia']]

# %%
# Instantiate the OneHotEncoder
encoder = OneHotEncoder(sparse=False, categories='auto')

X_train = lista_train.drop(['energia'], axis=1)
X_test = lista_test.drop(['energia'], axis=1)

# Fit the encoder and transform the data for both train and test dataframes
encoded_train = encoder.fit_transform(X_train)
encoded_test = encoder.transform(X_test)

# Now, 'encoded_train' and 'encoded_test' are numpy arrays, we can convert them back to dataframes:
X_train_scaled = pd.DataFrame(encoded_train, columns=encoder.get_feature_names_out(X_train.columns))
X_test_scaled = pd.DataFrame(encoded_test, columns=encoder.get_feature_names_out(X_test.columns))


y_test = lista_test['energia']
y_train = lista_train['energia']

# %%
"""
#############################################
# 4-LINEAR REGRESSION MODEL WITHFEATURE ENGINEERING #
#############################################
"""

model_lr = LinearRegression()
model_lr.fit(X_train_scaled, y_train)
r2_linreg_before = model_lr.score(X_test_scaled, y_test)
rmse_linreg_before = np.sqrt(mean_squared_error(y_test, model_lr.predict(X_test_scaled)))
print('LinearRegression R2 (Before feature engineering): ' + str(round(r2_linreg_before, 4)))
print('LinearRegression RMSE (Before feature engineering): ' + str(round(rmse_linreg_before, 4)))
# Out:
# LinearRegression R2 (Before feature engineering): 0.3361
# LinearRegression RMSE (Before feature engineering): 3.7005

# %%
fit_results = pd.DataFrame(y_train.copy())
fit_results.columns = ['Y_TRUE']
test_pred_results = pd.DataFrame(y_test.copy())
test_pred_results.columns = ['Y_TRUE']

fit_results['Y_FIT'] = model_lr.predict(X_train_scaled).ravel()
test_pred_results['Y_PRED'] = model_lr.predict(X_test_scaled)

fit_results = fit_results.sort_values(by = ['Y_TRUE']).reset_index(drop = True)
test_pred_results = test_pred_results.sort_values(by = ['Y_TRUE']).reset_index(drop = True)

#### SCATTER PLOT
plt.figure(figsize=(12,8))
plt.scatter(fit_results.index,  fit_results['Y_TRUE'], alpha = 0.4, s = 12, label = 'Y_TRUE')
plt.scatter(fit_results.index,  fit_results['Y_FIT'], alpha = 0.4, s = 12, label = 'Y_FIT')
plt.xlabel('Y_TRUE_RANK_ASENDING_ORDER (SORTED INDEX)')
plt.ylabel('Y')
plt.title('LinearRegression - BEFORE Feature Engineering' + '\n' + 'R2:' + str(round(r2_linreg_before, 4)) + ', RMSE:' + str(round(rmse_linreg_before, 2)))
plt.legend()

# %%
# assuming df is your DataFrame
df = lista_train.drop(['energia'], axis=1)

# replace zeros with np.nan
df = df.replace(0, np.nan)

# instantiate OneHotEncoder
enc = OneHotEncoder(sparse=False, handle_unknown='ignore')

# apply OneHotEncoder to df
onehot_df = enc.fit_transform(df)

# create H matrix
H = np.zeros(df.shape)

# specify the position of non-zero values in H
for i in range(df.shape[0]):
    for j in range(df.shape[1]):
        if not np.isnan(df.iloc[i, j]):
            H[i, j] = j+1  # or just 1, based on your requirements

# %%
X_train_array = np.concatenate((onehot_df, H), axis=1)
X_train_encoded = X_train_array.reshape((X_train_array.shape[0], X_train_array.shape[1], 1))

input_shape_train = (X_train_encoded.shape[1],1)
# assuming onehot_df_encoded and H are your input data and are numpy arrays
# reshape data for Conv1D, the format should be (n_samples, steps, channels)
onehot_df_encoded = onehot_df.reshape((170, 24, 1))
H_encoded = H.reshape((170, 4, 1))

# target data
y_train = np.array(y_train)
input_shape_train
# Out:
# (28, 1)

# %%
# assuming df is your DataFrame
df_test = lista_test.drop(['energia'], axis=1)

# replace zeros with np.nan
df_test = df_test.replace(0, np.nan)

# instantiate OneHotEncoder
enc = OneHotEncoder(sparse=False, handle_unknown='ignore')

# apply OneHotEncoder to df
onehot_df_test = enc.fit_transform(df_test)

# create H matrix
H_test = np.zeros(df_test.shape)

# specify the position of non-zero values in H
for i in range(df_test.shape[0]):
    for j in range(df_test.shape[1]):
        if not np.isnan(df_test.iloc[i, j]):
            H_test[i, j] = j+1  # or just 1, based on your requirements

# %%
onehot_df_test_encoded = onehot_df_test.reshape((onehot_df_test.shape[0], 24, 1))
H_test_encoded = H_test.reshape((H_test.shape[0], 4, 1))

X_test_array = np.concatenate((onehot_df_test, H_test), axis=1)
X_test_encoded = X_test_array.reshape((X_test_array.shape[0], X_test_array.shape[1], 1))
input_shape_test = (X_test_encoded.shape[1],1)
# target data
y_test = np.array(y_test)
y_test.shape
# Out:
# (1120,)

# %%
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import keras_tuner as kt
from keras_tuner import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters
from sklearn.utils import shuffle
from sklearn.linear_model import ElasticNet


def build_model(hp):
    # Input layers
    input_onehot_1d = Input(shape=(28, 1))

    # Flatten layers
    flat_onehot_1d = Flatten()(input_onehot_1d)

    # ElasticNet model
    elastic_net = ElasticNet(alpha=hp.Float('alpha', min_value=0.01, max_value=1.0),
                             l1_ratio=hp.Float('l1_ratio', min_value=0.01, max_value=1.0))

    # Output layer
    output_1d = Dense(1, activation='linear')(flat_onehot_1d)

    # Create model
    model_1d = Model(inputs=[input_onehot_1d], outputs=output_1d)

    # Compile model
    opt = Adam(learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4]))
    model_1d.compile(optimizer=opt, loss='mean_squared_error', metrics=['mae'])

    return model_1d



train_data = np.concatenate((onehot_df_encoded, H_encoded), axis = 1)
# assuming onehot_df_train, H_train, y_train are your training datasets
input_shape_onehot = (train_data.shape[1], 1)

train_data, y_train = shuffle(train_data, y_train)



tuner = RandomSearch(
    build_model,
    objective='val_loss',
    max_trials=10,
    executions_per_trial=15,
    directory='output',
    project_name='AirQuality',
    overwrite=True)

tuner.search_space_summary()

# Start the search for the best hyperparameters
tuner.search(train_data, y_train,
             epochs=80,
             validation_split=0.1)

# After the tuner is finished, retrieve the best model
best_model = tuner.get_best_models(num_models=1)[0]

# And its hyperparameters
best_hyperparameters = tuner.get_best_hyperparameters(1)[0]
# Out:
# Trial 10 Complete [00h 01m 13s]
# val_loss: 9.826077079772949
#
# Best val_loss So Far: 0.8383143941561381
# Total elapsed time: 00h 11m 51s
# INFO:tensorflow:Oracle triggered exit

# %%
# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the model with the optimal hyperparameters and train it on the data
model = tuner.hypermodel.build(best_hps)
history = model.fit(train_data, y_train, epochs=150, validation_split=0.1, verbose=1)

# Let's assume you have a test set
# Out:
# Epoch 1/150
# 5/5 [==============================] - 0s 30ms/step - loss: 23.8293 - mae: 4.2069 - val_loss: 13.9835 - val_mae: 3.2603
# Epoch 2/150
# 5/5 [==============================] - 0s 8ms/step - loss: 20.1240 - mae: 3.7976 - val_loss: 11.0927 - val_mae: 2.7979
# Epoch 3/150
# 5/5 [==============================] - 0s 9ms/step - loss: 16.9291 - mae: 3.3899 - val_loss: 8.7382 - val_mae: 2.3785
# Epoch 4/150
# 5/5 [==============================] - 0s 9ms/step - loss: 14.2118 - mae: 3.0172 - val_loss: 6.8929 - val_mae: 2.0293
# Epoch 5/150
# 5/5 [==============================] - 0s 10ms/step - loss: 11.9417 - mae: 2.6986 - val_loss: 5.5231 - val_mae: 1.8254
# Epoch 6/150
# 5/5 [==============================] - 0s 8ms/step - loss: 10.3422 - mae: 2.4271 - val_loss: 4.5428 - val_mae: 1.7129
# Epoch 7/150
# 5/5 [==============================] - 0s 9ms/step - loss: 8.8339 - mae: 2.2223 - val_loss: 3.9303 - val_mae: 1.6475
# Epoch 8/150
# 5/5 [==============================] - 0s 14ms/step - loss: 7.9377 - mae: 2.1110 - val_loss: 3.5646 - val_mae: 1.6095
# Epoch 9/150
# 5/5 [==============================] - 0s 8ms/step - loss: 7.1857 - mae: 2.0106 - val_loss: 3.3928 - val_mae: 1.5885
# Epoch 10/150
# 5/5 [==============================] - 0s 8ms/step - loss: 6.6819 - mae: 1.9480 - val_loss: 3.3431 - val_mae: 1.5758
# Epoch 11/150
# 5/5 [==============================] - 0s 9ms/step - loss: 6.3550 - mae: 1.9036 - val_loss: 3.3577 - val_mae: 1.5775
# Epoch 12/150
# 5/5 [==============================] - 0s 8ms/step - loss: 6.0654 - mae: 1.8651 - val_loss: 3.3987 - val_mae: 1.5897
# Epoch 13/150
# 5/5 [==============================] - 0s 9ms/step - loss: 5.9095 - mae: 1.8450 - val_loss: 3.4375 - val_mae: 1.6081
# Epoch 14/150
# 5/5 [==============================] - 0s 9ms/step - loss: 5.7514 - mae: 1.8231 - val_loss: 3.4509 - val_mae: 1.6136
# Epoch 15/150
# 5/5 [==============================] - 0s 9ms/step - loss: 5.6442 - mae: 1.8069 - val_loss: 3.4433 - val_mae: 1.6120
# Epoch 16/150
# 5/5 [==============================] - 0s 9ms/step - loss: 5.5448 - mae: 1.7937 - val_loss: 3.4075 - val_mae: 1.6025
# Epoch 17/150
# 5/5 [==============================] - 0s 9ms/step - loss: 5.4532 - mae: 1.7764 - val_loss: 3.3497 - val_mae: 1.5871
# Epoch 18/150
# 5/5 [==============================] - 0s 8ms/step - loss: 5.3640 - mae: 1.7604 - val_loss: 3.2683 - val_mae: 1.5659
# Epoch 19/150
# 5/5 [==============================] - 0s 13ms/step - loss: 5.2690 - mae: 1.7427 - val_loss: 3.1931 - val_mae: 1.5456
# Epoch 20/150
# 5/5 [==============================] - 0s 8ms/step - loss: 5.1942 - mae: 1.7275 - val_loss: 3.1164 - val_mae: 1.5246
# Epoch 21/150
# 5/5 [==============================] - 0s 8ms/step - loss: 5.1083 - mae: 1.7119 - val_loss: 3.0275 - val_mae: 1.5005
# Epoch 22/150
# 5/5 [==============================] - 0s 8ms/step - loss: 5.0297 - mae: 1.6946 - val_loss: 2.9424 - val_mae: 1.4766
# Epoch 23/150
# 5/5 [==============================] - 0s 8ms/step - loss: 4.9522 - mae: 1.6786 - val_loss: 2.8694 - val_mae: 1.4550
# Epoch 24/150
# 5/5 [==============================] - 0s 7ms/step - loss: 4.8824 - mae: 1.6634 - val_loss: 2.8044 - val_mae: 1.4355
# Epoch 25/150
# 5/5 [==============================] - 0s 8ms/step - loss: 4.8093 - mae: 1.6493 - val_loss: 2.7241 - val_mae: 1.4149
# Epoch 26/150
# 5/5 [==============================] - 0s 8ms/step - loss: 4.7414 - mae: 1.6348 - val_loss: 2.6551 - val_mae: 1.3960
# Epoch 27/150
# 5/5 [==============================] - 0s 9ms/step - loss: 4.6764 - mae: 1.6214 - val_loss: 2.5922 - val_mae: 1.3779
# Epoch 28/150
# 5/5 [==============================] - 0s 8ms/step - loss: 4.6146 - mae: 1.6076 - val_loss: 2.5393 - val_mae: 1.3624
# Epoch 29/150
# 5/5 [==============================] - 0s 8ms/step - loss: 4.5535 - mae: 1.5941 - val_loss: 2.4785 - val_mae: 1.3442
# Epoch 30/150
# 5/5 [==============================] - 0s 12ms/step - loss: 4.4942 - mae: 1.5807 - val_loss: 2.4087 - val_mae: 1.3233
# Epoch 31/150
# 5/5 [==============================] - 0s 9ms/step - loss: 4.4374 - mae: 1.5691 - val_loss: 2.3452 - val_mae: 1.3043
# Epoch 32/150
# 5/5 [==============================] - 0s 8ms/step - loss: 4.3809 - mae: 1.5569 - val_loss: 2.2902 - val_mae: 1.2868
# Epoch 33/150
# 5/5 [==============================] - 0s 7ms/step - loss: 4.3328 - mae: 1.5446 - val_loss: 2.2418 - val_mae: 1.2705
# Epoch 34/150
# 5/5 [==============================] - 0s 7ms/step - loss: 4.2800 - mae: 1.5332 - val_loss: 2.1808 - val_mae: 1.2501
# Epoch 35/150
# 5/5 [==============================] - 0s 7ms/step - loss: 4.2264 - mae: 1.5209 - val_loss: 2.1228 - val_mae: 1.2310
# Epoch 36/150
# 5/5 [==============================] - 0s 7ms/step - loss: 4.1867 - mae: 1.5117 - val_loss: 2.0721 - val_mae: 1.2126
# Epoch 37/150
# 5/5 [==============================] - 0s 7ms/step - loss: 4.1376 - mae: 1.5001 - val_loss: 2.0320 - val_mae: 1.1984
# Epoch 38/150
# 5/5 [==============================] - 0s 9ms/step - loss: 4.0920 - mae: 1.4894 - val_loss: 1.9938 - val_mae: 1.1858
# Epoch 39/150
# 5/5 [==============================] - 0s 13ms/step - loss: 4.0499 - mae: 1.4790 - val_loss: 1.9605 - val_mae: 1.1737
# Epoch 40/150
# 5/5 [==============================] - 0s 8ms/step - loss: 4.0049 - mae: 1.4673 - val_loss: 1.9107 - val_mae: 1.1596
# Epoch 41/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.9680 - mae: 1.4583 - val_loss: 1.8690 - val_mae: 1.1460
# Epoch 42/150
# 5/5 [==============================] - 0s 9ms/step - loss: 3.9368 - mae: 1.4490 - val_loss: 1.8250 - val_mae: 1.1323
# Epoch 43/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.8917 - mae: 1.4379 - val_loss: 1.7841 - val_mae: 1.1195
# Epoch 44/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.8558 - mae: 1.4283 - val_loss: 1.7506 - val_mae: 1.1074
# Epoch 45/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.8241 - mae: 1.4197 - val_loss: 1.7120 - val_mae: 1.0939
# Epoch 46/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.7895 - mae: 1.4095 - val_loss: 1.6820 - val_mae: 1.0821
# Epoch 47/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.7584 - mae: 1.4007 - val_loss: 1.6551 - val_mae: 1.0712
# Epoch 48/150
# 5/5 [==============================] - 0s 12ms/step - loss: 3.7316 - mae: 1.3933 - val_loss: 1.6192 - val_mae: 1.0592
# Epoch 49/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.6982 - mae: 1.3847 - val_loss: 1.5909 - val_mae: 1.0481
# Epoch 50/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.6765 - mae: 1.3775 - val_loss: 1.5634 - val_mae: 1.0358
# Epoch 51/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.6528 - mae: 1.3698 - val_loss: 1.5409 - val_mae: 1.0256
# Epoch 52/150
# 5/5 [==============================] - 0s 9ms/step - loss: 3.6190 - mae: 1.3602 - val_loss: 1.5105 - val_mae: 1.0151
# Epoch 53/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.5927 - mae: 1.3530 - val_loss: 1.4857 - val_mae: 1.0045
# Epoch 54/150
# 5/5 [==============================] - 0s 10ms/step - loss: 3.5794 - mae: 1.3472 - val_loss: 1.4561 - val_mae: 0.9925
# Epoch 55/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.5468 - mae: 1.3394 - val_loss: 1.4315 - val_mae: 0.9810
# Epoch 56/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.5264 - mae: 1.3323 - val_loss: 1.4043 - val_mae: 0.9706
# Epoch 57/150
# 5/5 [==============================] - 0s 12ms/step - loss: 3.5075 - mae: 1.3264 - val_loss: 1.3810 - val_mae: 0.9603
# Epoch 58/150
# 5/5 [==============================] - 0s 9ms/step - loss: 3.4823 - mae: 1.3188 - val_loss: 1.3554 - val_mae: 0.9489
# Epoch 59/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.4665 - mae: 1.3150 - val_loss: 1.3328 - val_mae: 0.9386
# Epoch 60/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.4489 - mae: 1.3093 - val_loss: 1.3074 - val_mae: 0.9292
# Epoch 61/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.4309 - mae: 1.3035 - val_loss: 1.2888 - val_mae: 0.9205
# Epoch 62/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.4133 - mae: 1.2978 - val_loss: 1.2659 - val_mae: 0.9103
# Epoch 63/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.3936 - mae: 1.2923 - val_loss: 1.2460 - val_mae: 0.9003
# Epoch 64/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.3779 - mae: 1.2879 - val_loss: 1.2333 - val_mae: 0.8917
# Epoch 65/150
# 5/5 [==============================] - 0s 13ms/step - loss: 3.3608 - mae: 1.2833 - val_loss: 1.2218 - val_mae: 0.8833
# Epoch 66/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.3478 - mae: 1.2800 - val_loss: 1.2114 - val_mae: 0.8754
# Epoch 67/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.3367 - mae: 1.2756 - val_loss: 1.1945 - val_mae: 0.8661
# Epoch 68/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.3234 - mae: 1.2713 - val_loss: 1.1791 - val_mae: 0.8578
# Epoch 69/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.3086 - mae: 1.2680 - val_loss: 1.1662 - val_mae: 0.8495
# Epoch 70/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.3013 - mae: 1.2672 - val_loss: 1.1462 - val_mae: 0.8395
# Epoch 71/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.2862 - mae: 1.2636 - val_loss: 1.1350 - val_mae: 0.8319
# Epoch 72/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.2766 - mae: 1.2607 - val_loss: 1.1211 - val_mae: 0.8263
# Epoch 73/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.2632 - mae: 1.2562 - val_loss: 1.1093 - val_mae: 0.8206
# Epoch 74/150
# 5/5 [==============================] - 0s 13ms/step - loss: 3.2529 - mae: 1.2517 - val_loss: 1.0996 - val_mae: 0.8138
# Epoch 75/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.2433 - mae: 1.2484 - val_loss: 1.0894 - val_mae: 0.8084
# Epoch 76/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.2328 - mae: 1.2454 - val_loss: 1.0757 - val_mae: 0.8045
# Epoch 77/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.2243 - mae: 1.2426 - val_loss: 1.0648 - val_mae: 0.8032
# Epoch 78/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.2145 - mae: 1.2393 - val_loss: 1.0581 - val_mae: 0.8001
# Epoch 79/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.2097 - mae: 1.2364 - val_loss: 1.0439 - val_mae: 0.7966
# Epoch 80/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.1991 - mae: 1.2320 - val_loss: 1.0313 - val_mae: 0.7926
# Epoch 81/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.1906 - mae: 1.2287 - val_loss: 1.0197 - val_mae: 0.7904
# Epoch 82/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.1829 - mae: 1.2286 - val_loss: 1.0122 - val_mae: 0.7910
# Epoch 83/150
# 5/5 [==============================] - 0s 11ms/step - loss: 3.1747 - mae: 1.2282 - val_loss: 1.0055 - val_mae: 0.7898
# Epoch 84/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.1728 - mae: 1.2281 - val_loss: 0.9995 - val_mae: 0.7887
# Epoch 85/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.1708 - mae: 1.2241 - val_loss: 0.9882 - val_mae: 0.7831
# Epoch 86/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.1536 - mae: 1.2196 - val_loss: 0.9818 - val_mae: 0.7816
# Epoch 87/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.1543 - mae: 1.2215 - val_loss: 0.9795 - val_mae: 0.7836
# Epoch 88/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.1438 - mae: 1.2197 - val_loss: 0.9699 - val_mae: 0.7797
# Epoch 89/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.1385 - mae: 1.2167 - val_loss: 0.9651 - val_mae: 0.7770
# Epoch 90/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.1365 - mae: 1.2182 - val_loss: 0.9622 - val_mae: 0.7781
# Epoch 91/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.1286 - mae: 1.2161 - val_loss: 0.9600 - val_mae: 0.7766
# Epoch 92/150
# 5/5 [==============================] - 0s 12ms/step - loss: 3.1275 - mae: 1.2130 - val_loss: 0.9468 - val_mae: 0.7722
# Epoch 93/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.1229 - mae: 1.2115 - val_loss: 0.9445 - val_mae: 0.7720
# Epoch 94/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.1164 - mae: 1.2071 - val_loss: 0.9304 - val_mae: 0.7652
# Epoch 95/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.1099 - mae: 1.2024 - val_loss: 0.9233 - val_mae: 0.7626
# Epoch 96/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.1038 - mae: 1.2004 - val_loss: 0.9151 - val_mae: 0.7613
# Epoch 97/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.1035 - mae: 1.2015 - val_loss: 0.9122 - val_mae: 0.7619
# Epoch 98/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0995 - mae: 1.2031 - val_loss: 0.9115 - val_mae: 0.7621
# Epoch 99/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0923 - mae: 1.2003 - val_loss: 0.9017 - val_mae: 0.7583
# Epoch 100/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0935 - mae: 1.1962 - val_loss: 0.8942 - val_mae: 0.7534
# Epoch 101/150
# 5/5 [==============================] - 0s 12ms/step - loss: 3.0872 - mae: 1.1927 - val_loss: 0.8850 - val_mae: 0.7510
# Epoch 102/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0821 - mae: 1.1900 - val_loss: 0.8795 - val_mae: 0.7495
# Epoch 103/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0796 - mae: 1.1902 - val_loss: 0.8846 - val_mae: 0.7505
# Epoch 104/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0796 - mae: 1.1937 - val_loss: 0.8785 - val_mae: 0.7499
# Epoch 105/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0750 - mae: 1.1912 - val_loss: 0.8723 - val_mae: 0.7465
# Epoch 106/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0722 - mae: 1.1874 - val_loss: 0.8643 - val_mae: 0.7430
# Epoch 107/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0668 - mae: 1.1854 - val_loss: 0.8648 - val_mae: 0.7436
# Epoch 108/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0651 - mae: 1.1852 - val_loss: 0.8669 - val_mae: 0.7441
# Epoch 109/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0620 - mae: 1.1839 - val_loss: 0.8629 - val_mae: 0.7421
# Epoch 110/150
# 5/5 [==============================] - 0s 14ms/step - loss: 3.0591 - mae: 1.1836 - val_loss: 0.8631 - val_mae: 0.7416
# Epoch 111/150
# 5/5 [==============================] - 0s 9ms/step - loss: 3.0565 - mae: 1.1833 - val_loss: 0.8633 - val_mae: 0.7414
# Epoch 112/150
# 5/5 [==============================] - 0s 10ms/step - loss: 3.0559 - mae: 1.1847 - val_loss: 0.8631 - val_mae: 0.7418
# Epoch 113/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0565 - mae: 1.1834 - val_loss: 0.8511 - val_mae: 0.7376
# Epoch 114/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0506 - mae: 1.1795 - val_loss: 0.8462 - val_mae: 0.7361
# Epoch 115/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0530 - mae: 1.1770 - val_loss: 0.8371 - val_mae: 0.7318
# Epoch 116/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0516 - mae: 1.1738 - val_loss: 0.8266 - val_mae: 0.7279
# Epoch 117/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0457 - mae: 1.1714 - val_loss: 0.8294 - val_mae: 0.7277
# Epoch 118/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0424 - mae: 1.1720 - val_loss: 0.8349 - val_mae: 0.7292
# Epoch 119/150
# 5/5 [==============================] - 0s 12ms/step - loss: 3.0419 - mae: 1.1771 - val_loss: 0.8479 - val_mae: 0.7332
# Epoch 120/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0461 - mae: 1.1830 - val_loss: 0.8562 - val_mae: 0.7351
# Epoch 121/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0434 - mae: 1.1808 - val_loss: 0.8390 - val_mae: 0.7311
# Epoch 122/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0375 - mae: 1.1737 - val_loss: 0.8255 - val_mae: 0.7265
# Epoch 123/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0379 - mae: 1.1687 - val_loss: 0.8154 - val_mae: 0.7234
# Epoch 124/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0345 - mae: 1.1665 - val_loss: 0.8175 - val_mae: 0.7226
# Epoch 125/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0340 - mae: 1.1671 - val_loss: 0.8161 - val_mae: 0.7225
# Epoch 126/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0328 - mae: 1.1646 - val_loss: 0.8064 - val_mae: 0.7187
# Epoch 127/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0296 - mae: 1.1615 - val_loss: 0.8030 - val_mae: 0.7165
# Epoch 128/150
# 5/5 [==============================] - 0s 12ms/step - loss: 3.0334 - mae: 1.1643 - val_loss: 0.8095 - val_mae: 0.7191
# Epoch 129/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0290 - mae: 1.1651 - val_loss: 0.8069 - val_mae: 0.7172
# Epoch 130/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0250 - mae: 1.1620 - val_loss: 0.7967 - val_mae: 0.7143
# Epoch 131/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0251 - mae: 1.1588 - val_loss: 0.7901 - val_mae: 0.7113
# Epoch 132/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0239 - mae: 1.1568 - val_loss: 0.7893 - val_mae: 0.7108
# Epoch 133/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0245 - mae: 1.1555 - val_loss: 0.7818 - val_mae: 0.7090
# Epoch 134/150
# 5/5 [==============================] - 0s 9ms/step - loss: 3.0234 - mae: 1.1546 - val_loss: 0.7809 - val_mae: 0.7088
# Epoch 135/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0239 - mae: 1.1572 - val_loss: 0.7953 - val_mae: 0.7129
# Epoch 136/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0218 - mae: 1.1608 - val_loss: 0.8028 - val_mae: 0.7154
# Epoch 137/150
# 5/5 [==============================] - 0s 11ms/step - loss: 3.0193 - mae: 1.1610 - val_loss: 0.8011 - val_mae: 0.7135
# Epoch 138/150
# 5/5 [==============================] - 0s 9ms/step - loss: 3.0236 - mae: 1.1611 - val_loss: 0.7974 - val_mae: 0.7132
# Epoch 139/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0176 - mae: 1.1553 - val_loss: 0.7862 - val_mae: 0.7077
# Epoch 140/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0157 - mae: 1.1525 - val_loss: 0.7801 - val_mae: 0.7065
# Epoch 141/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.0258 - mae: 1.1489 - val_loss: 0.7658 - val_mae: 0.7005
# Epoch 142/150
# 5/5 [==============================] - 0s 20ms/step - loss: 3.0167 - mae: 1.1468 - val_loss: 0.7795 - val_mae: 0.7049
# Epoch 143/150
# 5/5 [==============================] - 0s 9ms/step - loss: 3.0157 - mae: 1.1506 - val_loss: 0.7848 - val_mae: 0.7063
# Epoch 144/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0179 - mae: 1.1544 - val_loss: 0.7915 - val_mae: 0.7090
# Epoch 145/150
# 5/5 [==============================] - 0s 7ms/step - loss: 3.0137 - mae: 1.1532 - val_loss: 0.7849 - val_mae: 0.7072
# Epoch 146/150
# 5/5 [==============================] - 0s 13ms/step - loss: 3.0124 - mae: 1.1503 - val_loss: 0.7800 - val_mae: 0.7035
# Epoch 147/150
# 5/5 [==============================] - 0s 10ms/step - loss: 3.0158 - mae: 1.1459 - val_loss: 0.7572 - val_mae: 0.6963
# Epoch 148/150
# 5/5 [==============================] - 0s 18ms/step - loss: 3.0111 - mae: 1.1422 - val_loss: 0.7592 - val_mae: 0.6965
# Epoch 149/150
# 5/5 [==============================] - 0s 12ms/step - loss: 3.0140 - mae: 1.1445 - val_loss: 0.7716 - val_mae: 0.6994
# Epoch 150/150
# 5/5 [==============================] - 0s 9ms/step - loss: 3.0148 - mae: 1.1486 - val_loss: 0.7744 - val_mae: 0.7017

# %%
#onehot_df_test_encoded, H_test_encoded = prepare_test_data(onehot_df_test, H_test)  # You need to ensure that your test data is prepared in the same way as your training data
test_data = np.concatenate((onehot_df_test_encoded, H_test_encoded), axis = 1)
# Now you can make predictions on your test set
predictions = model.predict(test_data)
# Out:
# 35/35 [==============================] - 0s 677us/step

# %%
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

print('Mean Squared Error (MSE): ', mse)
print('Root Mean Squared Error (RMSE): ', rmse)
print('Mean Absolute Error (MAE): ', mae)
print('R-squared Score (R^2): ', r2)
# Out:
# Mean Squared Error (MSE):  14.705627372742407
# Root Mean Squared Error (RMSE):  3.8347916987422415
# Mean Absolute Error (MAE):  2.5974317055489564
# R-squared Score (R^2):  0.28700261423540985

# %%
import matplotlib.pyplot as plt

# plot predicted vs real values
plt.figure(figsize=(10, 5))
plt.plot(y_test, label='Real')
plt.plot(predictions, label='Predicted')
plt.legend()
plt.show()

# %%
differences = predictions.flatten() - y_test.flatten() # This will give the difference between your predictions and the actual values

#Create a figure with two subplots: a histogram of the differences and a scatter plot of predicted vs real values
fig, axs = plt.subplots(nrows=2, figsize=(10, 15))

#Plot histogram
axs[0].hist(differences, bins=20, density=True)
axs[0].set_title('Histogram of differences between predicted and actual values')
axs[0].set_xlabel('Differences')
axs[0].set_ylabel('Density')

#Plot scatter
axs[1].scatter(y_test, predictions, alpha=0.5)
axs[1].set_title('Scatter plot of predicted vs actual values')
axs[1].set_xlabel('Actual Values')
axs[1].set_ylabel('Predicted Values')

#Draw a diagonal line on the scatterplot
lims = [np.min([axs[1].get_xlim(), axs[1].get_ylim()]), # min of both axes
np.max([axs[1].get_xlim(), axs[1].get_ylim()])] # max of both axes
axs[1].plot(lims, lims, 'k-', alpha=0.75, zorder=0)
axs[1].set_xlim(lims)
axs[1].set_ylim(lims)

plt.tight_layout()
plt.show()
