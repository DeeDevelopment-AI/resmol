# %%
from IPython.display import Image
from IPython.display import display, HTML
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from fboost import outlier_iqr, DataPreparator, FeatureBoosterRegressor
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import OneHotEncoder

from sklearn.linear_model import LinearRegression, Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.inspection import permutation_importance
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras

from sklearn.metrics import mean_squared_error
from math import sqrt
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score


import warnings
warnings.filterwarnings('ignore')

# Set a seed value
seed_value= 0
# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)
# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)
# 3. Set `numpy` pseudo-random generator at a fixed value
np.random.seed(seed_value)

# %%
data = pd.read_csv('../data/raw/alldata.csv')
data.columns = ['familia','indice_fam','subposicion_1','subposicion_2','subposicion_3','subposicion_4', 'energia']
mask = (data[['subposicion_1','subposicion_2','subposicion_3','subposicion_4']] == 0).sum(axis=1) > 1
lista_train = data.loc[mask,['subposicion_1','subposicion_2','subposicion_3','subposicion_4','energia']]
lista_test = data.loc[~mask,['subposicion_1','subposicion_2','subposicion_3','subposicion_4','energia']]

# %%
# Instantiate the OneHotEncoder
encoder = OneHotEncoder(sparse=False, categories='auto')

X_train = lista_train.drop(['energia'], axis=1)
X_test = lista_test.drop(['energia'], axis=1)

# Fit the encoder and transform the data for both train and test dataframes
encoded_train = encoder.fit_transform(X_train)
encoded_test = encoder.transform(X_test)

# Now, 'encoded_train' and 'encoded_test' are numpy arrays, we can convert them back to dataframes:
X_train_scaled = pd.DataFrame(encoded_train, columns=encoder.get_feature_names_out(X_train.columns))
X_test_scaled = pd.DataFrame(encoded_test, columns=encoder.get_feature_names_out(X_test.columns))


y_test = lista_test['energia']
y_train = lista_train['energia']

# %%
"""
#############################################
# 4-LINEAR REGRESSION MODEL WITHFEATURE ENGINEERING #
#############################################
"""

model_lr = LinearRegression()
model_lr.fit(X_train_scaled, y_train)
r2_linreg_before = model_lr.score(X_test_scaled, y_test)
rmse_linreg_before = np.sqrt(mean_squared_error(y_test, model_lr.predict(X_test_scaled)))
print('LinearRegression R2 (Before feature engineering): ' + str(round(r2_linreg_before, 4)))
print('LinearRegression RMSE (Before feature engineering): ' + str(round(rmse_linreg_before, 4)))
# Out:
# LinearRegression R2 (Before feature engineering): 0.3361
# LinearRegression RMSE (Before feature engineering): 3.7005

# %%
fit_results = pd.DataFrame(y_train.copy())
fit_results.columns = ['Y_TRUE']
test_pred_results = pd.DataFrame(y_test.copy())
test_pred_results.columns = ['Y_TRUE']

fit_results['Y_FIT'] = model_lr.predict(X_train_scaled).ravel()
test_pred_results['Y_PRED'] = model_lr.predict(X_test_scaled)

fit_results = fit_results.sort_values(by = ['Y_TRUE']).reset_index(drop = True)
test_pred_results = test_pred_results.sort_values(by = ['Y_TRUE']).reset_index(drop = True)

#### SCATTER PLOT
plt.figure(figsize=(12,8))
plt.scatter(fit_results.index,  fit_results['Y_TRUE'], alpha = 0.4, s = 12, label = 'Y_TRUE')
plt.scatter(fit_results.index,  fit_results['Y_FIT'], alpha = 0.4, s = 12, label = 'Y_FIT')
plt.xlabel('Y_TRUE_RANK_ASENDING_ORDER (SORTED INDEX)')
plt.ylabel('Y')
plt.title('LinearRegression - BEFORE Feature Engineering' + '\n' + 'R2:' + str(round(r2_linreg_before, 4)) + ', RMSE:' + str(round(rmse_linreg_before, 2)))
plt.legend()

# %%
# assuming df is your DataFrame
df = lista_train.drop(['energia'], axis=1)

# replace zeros with np.nan
df = df.replace(0, np.nan)

# instantiate OneHotEncoder
enc = OneHotEncoder(sparse=False, handle_unknown='ignore')

# apply OneHotEncoder to df
onehot_df = enc.fit_transform(df)

# create H matrix
H = np.zeros(df.shape)

# specify the position of non-zero values in H
for i in range(df.shape[0]):
    for j in range(df.shape[1]):
        if not np.isnan(df.iloc[i, j]):
            H[i, j] = j+1  # or just 1, based on your requirements

# %%
X_train_array = np.concatenate((onehot_df, H), axis=1)
X_train_encoded = X_train_array.reshape((X_train_array.shape[0], X_train_array.shape[1], 1))

input_shape_train = (X_train_encoded.shape[1],1)
# assuming onehot_df_encoded and H are your input data and are numpy arrays
# reshape data for Conv1D, the format should be (n_samples, steps, channels)
onehot_df_encoded = onehot_df.reshape((170, 24, 1))
H_encoded = H.reshape((170, 4, 1))

# target data
y_train = np.array(y_train)
input_shape_train
# Out:
# (28, 1)

# %%
# assuming df is your DataFrame
df_test = lista_test.drop(['energia'], axis=1)

# replace zeros with np.nan
df_test = df_test.replace(0, np.nan)

# instantiate OneHotEncoder
enc = OneHotEncoder(sparse=False, handle_unknown='ignore')

# apply OneHotEncoder to df
onehot_df_test = enc.fit_transform(df_test)

# create H matrix
H_test = np.zeros(df_test.shape)

# specify the position of non-zero values in H
for i in range(df_test.shape[0]):
    for j in range(df_test.shape[1]):
        if not np.isnan(df_test.iloc[i, j]):
            H_test[i, j] = j+1  # or just 1, based on your requirements

# %%
onehot_df_test_encoded = onehot_df_test.reshape((onehot_df_test.shape[0], 24, 1))
H_test_encoded = H_test.reshape((H_test.shape[0], 4, 1))

X_test_array = np.concatenate((onehot_df_test, H_test), axis=1)
X_test_encoded = X_test_array.reshape((X_test_array.shape[0], X_test_array.shape[1], 1))
input_shape_test = (X_test_encoded.shape[1],1)
# target data
y_test = np.array(y_test)
y_test.shape
# Out:
# (1120,)

# %%
import keras_tuner as kt
from keras_tuner import RandomSearch
from keras_tuner.engine.hyperparameters import HyperParameters
from sklearn.utils import shuffle
from tensorflow.keras.layers import Input, Flatten, Dense, Layer, BatchNormalization, Multiply
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import tensorflow.keras.backend as K
from sklearn.linear_model import Lasso
from kerastuner import HyperModel


class MyHyperModel(HyperModel):
    def __init__(self, input_dim, output_dim):
        self.input_dim = input_dim
        self.output_dim = output_dim

    def build(self, hp):
        # Define Multiply Network
        input_layer_1 = Input(shape=(self.input_dim,))
        input_layer_2 = Input(shape=(self.input_dim,))

        dense_units = hp.Int('dense_units', min_value=256, max_value=1024, step=256)
        dense_1 = Dense(dense_units, activation='relu')(input_layer_1)
        dense_2 = Dense(dense_units, activation='relu')(input_layer_2)

        multiply_layer = Multiply()([dense_1, dense_2])

        output_layer = Dense(self.output_dim, activation='linear')(multiply_layer)

        multiply_model = Model(inputs=[input_layer_1, input_layer_2], outputs=output_layer)

        # Compile model
        opt = Adam(learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4]))
        multiply_model.compile(optimizer=opt, loss='mean_squared_error', metrics=['mae'])

        return multiply_model

# Assume you have X_train, Y_train, X_val, Y_val as your training and validation data

input_dim = 28 # Please replace with your input dimension
output_dim = 1 # Please replace with your output dimension

hypermodel = MyHyperModel(input_dim, output_dim)

from kerastuner.tuners import RandomSearch

tuner = RandomSearch(
    hypermodel,
    objective='val_loss',
    max_trials=5,
    executions_per_trial=3,
    directory='output',
    project_name='multiply_model',
    overwrite = True
)

train_data = np.concatenate((onehot_df_encoded, H_encoded), axis = 1)
# assuming onehot_df_train, H_train, y_train are your training datasets
input_shape_onehot = (train_data.shape[1], 1)

train_data, y_train = shuffle(train_data, y_train)

tuner.search_space_summary()

tuner.search([train_data, train_data], y_train,
             epochs=80,
             validation_split=0.1)


# After the tuner is finished, retrieve the best model
best_model = tuner.get_best_models(num_models=1)[0]

# And its hyperparameters
best_hyperparameters = tuner.get_best_hyperparameters(1)[0]

print(f"The hyperparameter search is complete. The optimal number of units in the densely-connected layers is {best_hyperparameters.get('dense_units')} and the optimal learning rate for the optimizer is {best_hyperparameters.get('learning_rate')}.")
# Out:
# Trial 5 Complete [00h 00m 13s]
# val_loss: 0.4078226486841838
#
# Best val_loss So Far: 0.4078226486841838
# Total elapsed time: 00h 01m 09s
# INFO:tensorflow:Oracle triggered exit
# The hyperparameter search is complete. The optimal number of units in the densely-connected layers is 768 and the optimal learning rate for the optimizer is 0.01.

# %%
# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]

# Build the model with the optimal hyperparameters and train it on the data
model = tuner.hypermodel.build(best_hps)
history = model.fit([train_data, train_data], y_train, epochs=150, validation_split=0.1, verbose=1)

# Let's assume you have a test set
# Out:
# Epoch 1/150
# 5/5 [==============================] - 1s 35ms/step - loss: 12.7814 - mae: 2.7841 - val_loss: 8.0343 - val_mae: 2.5406
# Epoch 2/150
# 5/5 [==============================] - 0s 8ms/step - loss: 6.0682 - mae: 1.9023 - val_loss: 1.7362 - val_mae: 1.1300
# Epoch 3/150
# 5/5 [==============================] - 0s 8ms/step - loss: 3.8510 - mae: 1.4264 - val_loss: 1.2159 - val_mae: 0.8724
# Epoch 4/150
# 5/5 [==============================] - 0s 9ms/step - loss: 2.9224 - mae: 1.2929 - val_loss: 1.3570 - val_mae: 0.9938
# Epoch 5/150
# 5/5 [==============================] - 0s 9ms/step - loss: 1.9150 - mae: 0.9784 - val_loss: 0.9109 - val_mae: 0.6991
# Epoch 6/150
# 5/5 [==============================] - 0s 8ms/step - loss: 1.8148 - mae: 0.9684 - val_loss: 0.8007 - val_mae: 0.7119
# Epoch 7/150
# 5/5 [==============================] - 0s 8ms/step - loss: 1.4698 - mae: 0.8781 - val_loss: 0.8716 - val_mae: 0.7554
# Epoch 8/150
# 5/5 [==============================] - 0s 8ms/step - loss: 1.3342 - mae: 0.8507 - val_loss: 0.8110 - val_mae: 0.6948
# Epoch 9/150
# 5/5 [==============================] - 0s 8ms/step - loss: 1.1747 - mae: 0.7658 - val_loss: 0.7102 - val_mae: 0.6731
# Epoch 10/150
# 5/5 [==============================] - 0s 9ms/step - loss: 1.1416 - mae: 0.7821 - val_loss: 0.7262 - val_mae: 0.6365
# Epoch 11/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.9679 - mae: 0.7006 - val_loss: 0.9791 - val_mae: 0.7295
# Epoch 12/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.8781 - mae: 0.6631 - val_loss: 0.6392 - val_mae: 0.6339
# Epoch 13/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7938 - mae: 0.6239 - val_loss: 0.7352 - val_mae: 0.6609
# Epoch 14/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.6750 - mae: 0.5829 - val_loss: 0.7869 - val_mae: 0.6275
# Epoch 15/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.5956 - mae: 0.5533 - val_loss: 0.5275 - val_mae: 0.5697
# Epoch 16/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.5774 - mae: 0.5519 - val_loss: 0.5867 - val_mae: 0.5811
# Epoch 17/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4881 - mae: 0.4952 - val_loss: 0.5084 - val_mae: 0.5695
# Epoch 18/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5207 - mae: 0.5506 - val_loss: 0.7083 - val_mae: 0.6102
# Epoch 19/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4495 - mae: 0.5136 - val_loss: 0.6008 - val_mae: 0.6065
# Epoch 20/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.4473 - mae: 0.5184 - val_loss: 0.7396 - val_mae: 0.6501
# Epoch 21/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.3689 - mae: 0.4635 - val_loss: 0.6481 - val_mae: 0.6467
# Epoch 22/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.4283 - mae: 0.5301 - val_loss: 0.7596 - val_mae: 0.6812
# Epoch 23/150
# 5/5 [==============================] - 0s 13ms/step - loss: 0.4481 - mae: 0.5216 - val_loss: 0.5535 - val_mae: 0.5916
# Epoch 24/150
# 5/5 [==============================] - 0s 11ms/step - loss: 0.2949 - mae: 0.4447 - val_loss: 0.7416 - val_mae: 0.7094
# Epoch 25/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2323 - mae: 0.3480 - val_loss: 0.5873 - val_mae: 0.6135
# Epoch 26/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2175 - mae: 0.3618 - val_loss: 0.6829 - val_mae: 0.6332
# Epoch 27/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1469 - mae: 0.3011 - val_loss: 0.5923 - val_mae: 0.5761
# Epoch 28/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1182 - mae: 0.2744 - val_loss: 0.5922 - val_mae: 0.5806
# Epoch 29/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1141 - mae: 0.2622 - val_loss: 0.5667 - val_mae: 0.5676
# Epoch 30/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0866 - mae: 0.2254 - val_loss: 0.6088 - val_mae: 0.5830
# Epoch 31/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0734 - mae: 0.2120 - val_loss: 0.5333 - val_mae: 0.5933
# Epoch 32/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0580 - mae: 0.1816 - val_loss: 0.5414 - val_mae: 0.5827
# Epoch 33/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0508 - mae: 0.1687 - val_loss: 0.5684 - val_mae: 0.5838
# Epoch 34/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0445 - mae: 0.1683 - val_loss: 0.5509 - val_mae: 0.6092
# Epoch 35/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0451 - mae: 0.1740 - val_loss: 0.5713 - val_mae: 0.5864
# Epoch 36/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0353 - mae: 0.1420 - val_loss: 0.5821 - val_mae: 0.6194
# Epoch 37/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0497 - mae: 0.1735 - val_loss: 0.6105 - val_mae: 0.5970
# Epoch 38/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0352 - mae: 0.1492 - val_loss: 0.5592 - val_mae: 0.6309
# Epoch 39/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0326 - mae: 0.1366 - val_loss: 0.5419 - val_mae: 0.6044
# Epoch 40/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0240 - mae: 0.1054 - val_loss: 0.5620 - val_mae: 0.5775
# Epoch 41/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0186 - mae: 0.1089 - val_loss: 0.5425 - val_mae: 0.6080
# Epoch 42/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0134 - mae: 0.0949 - val_loss: 0.5626 - val_mae: 0.5946
# Epoch 43/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0207 - mae: 0.1102 - val_loss: 0.5571 - val_mae: 0.6180
# Epoch 44/150
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0187 - mae: 0.1049 - val_loss: 0.5634 - val_mae: 0.6169
# Epoch 45/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0175 - mae: 0.1041 - val_loss: 0.5662 - val_mae: 0.6018
# Epoch 46/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0203 - mae: 0.1126 - val_loss: 0.5832 - val_mae: 0.6412
# Epoch 47/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0192 - mae: 0.1057 - val_loss: 0.5603 - val_mae: 0.6182
# Epoch 48/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0234 - mae: 0.1104 - val_loss: 0.5365 - val_mae: 0.6120
# Epoch 49/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0150 - mae: 0.0908 - val_loss: 0.5027 - val_mae: 0.5902
# Epoch 50/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0179 - mae: 0.0988 - val_loss: 0.5393 - val_mae: 0.5811
# Epoch 51/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0237 - mae: 0.1173 - val_loss: 0.5916 - val_mae: 0.6385
# Epoch 52/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0201 - mae: 0.1082 - val_loss: 0.5760 - val_mae: 0.6138
# Epoch 53/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0160 - mae: 0.0934 - val_loss: 0.5638 - val_mae: 0.5876
# Epoch 54/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0154 - mae: 0.0988 - val_loss: 0.5494 - val_mae: 0.6109
# Epoch 55/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0771 - val_loss: 0.5517 - val_mae: 0.6099
# Epoch 56/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0093 - mae: 0.0680 - val_loss: 0.5559 - val_mae: 0.6148
# Epoch 57/150
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0073 - mae: 0.0618 - val_loss: 0.5527 - val_mae: 0.6130
# Epoch 58/150
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0103 - mae: 0.0831 - val_loss: 0.5780 - val_mae: 0.6097
# Epoch 59/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0114 - mae: 0.0826 - val_loss: 0.5680 - val_mae: 0.6197
# Epoch 60/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0134 - mae: 0.0858 - val_loss: 0.5383 - val_mae: 0.6097
# Epoch 61/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0090 - mae: 0.0645 - val_loss: 0.5661 - val_mae: 0.6066
# Epoch 62/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0061 - mae: 0.0520 - val_loss: 0.5606 - val_mae: 0.6173
# Epoch 63/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0069 - mae: 0.0577 - val_loss: 0.5399 - val_mae: 0.5949
# Epoch 64/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0063 - mae: 0.0596 - val_loss: 0.5507 - val_mae: 0.6069
# Epoch 65/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0057 - mae: 0.0590 - val_loss: 0.5435 - val_mae: 0.6182
# Epoch 66/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0079 - mae: 0.0693 - val_loss: 0.5481 - val_mae: 0.5892
# Epoch 67/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0081 - mae: 0.0687 - val_loss: 0.5618 - val_mae: 0.6178
# Epoch 68/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0098 - mae: 0.0744 - val_loss: 0.5559 - val_mae: 0.6189
# Epoch 69/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0126 - mae: 0.0852 - val_loss: 0.5473 - val_mae: 0.6063
# Epoch 70/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0081 - mae: 0.0679 - val_loss: 0.5487 - val_mae: 0.6123
# Epoch 71/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0077 - mae: 0.0555 - val_loss: 0.5486 - val_mae: 0.6110
# Epoch 72/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0049 - mae: 0.0514 - val_loss: 0.5769 - val_mae: 0.6257
# Epoch 73/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0059 - mae: 0.0569 - val_loss: 0.5590 - val_mae: 0.6061
# Epoch 74/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0055 - mae: 0.0535 - val_loss: 0.5668 - val_mae: 0.6026
# Epoch 75/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0038 - mae: 0.0431 - val_loss: 0.5480 - val_mae: 0.6088
# Epoch 76/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0036 - mae: 0.0440 - val_loss: 0.5543 - val_mae: 0.6136
# Epoch 77/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0025 - mae: 0.0385 - val_loss: 0.5669 - val_mae: 0.6218
# Epoch 78/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0025 - mae: 0.0383 - val_loss: 0.5585 - val_mae: 0.6128
# Epoch 79/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0033 - mae: 0.0443 - val_loss: 0.5527 - val_mae: 0.6032
# Epoch 80/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0029 - mae: 0.0399 - val_loss: 0.5565 - val_mae: 0.6048
# Epoch 81/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0025 - mae: 0.0374 - val_loss: 0.5617 - val_mae: 0.6168
# Epoch 82/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0021 - mae: 0.0354 - val_loss: 0.5585 - val_mae: 0.6131
# Epoch 83/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0015 - mae: 0.0293 - val_loss: 0.5631 - val_mae: 0.6118
# Epoch 84/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0017 - mae: 0.0311 - val_loss: 0.5552 - val_mae: 0.6086
# Epoch 85/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0021 - mae: 0.0335 - val_loss: 0.5558 - val_mae: 0.6099
# Epoch 86/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0023 - mae: 0.0376 - val_loss: 0.5640 - val_mae: 0.6094
# Epoch 87/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0027 - mae: 0.0387 - val_loss: 0.5514 - val_mae: 0.6100
# Epoch 88/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0019 - mae: 0.0312 - val_loss: 0.5520 - val_mae: 0.6106
# Epoch 89/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0027 - mae: 0.0330 - val_loss: 0.5564 - val_mae: 0.6143
# Epoch 90/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0030 - mae: 0.0383 - val_loss: 0.5686 - val_mae: 0.6097
# Epoch 91/150
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0032 - mae: 0.0427 - val_loss: 0.5677 - val_mae: 0.6231
# Epoch 92/150
# 5/5 [==============================] - 0s 11ms/step - loss: 0.0030 - mae: 0.0396 - val_loss: 0.5623 - val_mae: 0.6135
# Epoch 93/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0029 - mae: 0.0389 - val_loss: 0.5595 - val_mae: 0.6131
# Epoch 94/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0037 - mae: 0.0472 - val_loss: 0.5669 - val_mae: 0.6145
# Epoch 95/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0035 - mae: 0.0411 - val_loss: 0.5602 - val_mae: 0.6183
# Epoch 96/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0044 - mae: 0.0469 - val_loss: 0.5743 - val_mae: 0.6084
# Epoch 97/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0046 - mae: 0.0513 - val_loss: 0.5565 - val_mae: 0.6200
# Epoch 98/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0089 - mae: 0.0684 - val_loss: 0.5741 - val_mae: 0.6182
# Epoch 99/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0158 - mae: 0.0870 - val_loss: 0.5542 - val_mae: 0.6209
# Epoch 100/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0213 - mae: 0.1038 - val_loss: 0.5869 - val_mae: 0.5968
# Epoch 101/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0274 - mae: 0.1269 - val_loss: 0.5962 - val_mae: 0.6272
# Epoch 102/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0350 - mae: 0.1466 - val_loss: 0.5554 - val_mae: 0.6101
# Epoch 103/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0481 - mae: 0.1644 - val_loss: 0.5809 - val_mae: 0.5920
# Epoch 104/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0888 - mae: 0.2231 - val_loss: 0.5859 - val_mae: 0.6122
# Epoch 105/150
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1057 - mae: 0.2302 - val_loss: 0.6347 - val_mae: 0.6471
# Epoch 106/150
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1088 - mae: 0.2500 - val_loss: 0.6493 - val_mae: 0.6411
# Epoch 107/150
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1367 - mae: 0.2838 - val_loss: 0.5726 - val_mae: 0.6287
# Epoch 108/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1348 - mae: 0.2759 - val_loss: 0.6388 - val_mae: 0.6418
# Epoch 109/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1273 - mae: 0.2511 - val_loss: 0.6185 - val_mae: 0.6515
# Epoch 110/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0889 - mae: 0.2088 - val_loss: 0.5181 - val_mae: 0.6098
# Epoch 111/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0514 - mae: 0.1690 - val_loss: 0.5672 - val_mae: 0.6022
# Epoch 112/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0481 - mae: 0.1661 - val_loss: 0.4806 - val_mae: 0.5943
# Epoch 113/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0597 - mae: 0.1773 - val_loss: 0.5893 - val_mae: 0.6363
# Epoch 114/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0867 - mae: 0.1965 - val_loss: 0.5529 - val_mae: 0.6325
# Epoch 115/150
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0723 - mae: 0.1854 - val_loss: 0.5912 - val_mae: 0.6339
# Epoch 116/150
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0826 - mae: 0.2071 - val_loss: 0.5772 - val_mae: 0.6326
# Epoch 117/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0723 - mae: 0.1954 - val_loss: 0.5309 - val_mae: 0.5982
# Epoch 118/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0521 - mae: 0.1688 - val_loss: 0.5509 - val_mae: 0.6267
# Epoch 119/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0695 - mae: 0.1983 - val_loss: 0.5244 - val_mae: 0.6121
# Epoch 120/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0656 - mae: 0.1938 - val_loss: 0.6317 - val_mae: 0.6412
# Epoch 121/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0663 - mae: 0.1936 - val_loss: 0.5770 - val_mae: 0.6312
# Epoch 122/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0370 - mae: 0.1431 - val_loss: 0.5591 - val_mae: 0.6238
# Epoch 123/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0596 - mae: 0.1704 - val_loss: 0.5491 - val_mae: 0.5972
# Epoch 124/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0752 - mae: 0.1932 - val_loss: 0.5638 - val_mae: 0.6289
# Epoch 125/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1643 - mae: 0.2830 - val_loss: 0.5371 - val_mae: 0.6137
# Epoch 126/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1646 - mae: 0.2937 - val_loss: 0.5695 - val_mae: 0.6149
# Epoch 127/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0978 - mae: 0.2252 - val_loss: 0.5732 - val_mae: 0.6550
# Epoch 128/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0656 - mae: 0.1903 - val_loss: 0.6813 - val_mae: 0.6952
# Epoch 129/150
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1085 - mae: 0.2587 - val_loss: 0.7562 - val_mae: 0.7046
# Epoch 130/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1256 - mae: 0.2658 - val_loss: 0.6272 - val_mae: 0.6648
# Epoch 131/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1747 - mae: 0.3087 - val_loss: 0.6066 - val_mae: 0.6386
# Epoch 132/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1108 - mae: 0.2415 - val_loss: 0.6093 - val_mae: 0.6158
# Epoch 133/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1166 - mae: 0.2549 - val_loss: 0.6581 - val_mae: 0.6863
# Epoch 134/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0768 - mae: 0.1997 - val_loss: 0.6850 - val_mae: 0.7090
# Epoch 135/150
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0642 - mae: 0.1947 - val_loss: 0.5712 - val_mae: 0.6116
# Epoch 136/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0362 - mae: 0.1454 - val_loss: 0.5524 - val_mae: 0.5932
# Epoch 137/150
# 5/5 [==============================] - 0s 10ms/step - loss: 0.0244 - mae: 0.1216 - val_loss: 0.5548 - val_mae: 0.6285
# Epoch 138/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0212 - mae: 0.1184 - val_loss: 0.5518 - val_mae: 0.6148
# Epoch 139/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0187 - mae: 0.1027 - val_loss: 0.5456 - val_mae: 0.5974
# Epoch 140/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0152 - mae: 0.0948 - val_loss: 0.5965 - val_mae: 0.6406
# Epoch 141/150
# 5/5 [==============================] - 0s 12ms/step - loss: 0.0212 - mae: 0.1085 - val_loss: 0.5392 - val_mae: 0.5970
# Epoch 142/150
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0094 - mae: 0.0741 - val_loss: 0.5625 - val_mae: 0.6237
# Epoch 143/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0083 - mae: 0.0690 - val_loss: 0.5553 - val_mae: 0.6238
# Epoch 144/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0112 - mae: 0.0778 - val_loss: 0.5570 - val_mae: 0.6071
# Epoch 145/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0167 - mae: 0.1043 - val_loss: 0.5629 - val_mae: 0.6220
# Epoch 146/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0119 - mae: 0.0846 - val_loss: 0.5638 - val_mae: 0.6203
# Epoch 147/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0058 - mae: 0.0572 - val_loss: 0.5426 - val_mae: 0.6076
# Epoch 148/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0100 - mae: 0.0768 - val_loss: 0.5362 - val_mae: 0.6106
# Epoch 149/150
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0081 - mae: 0.0694 - val_loss: 0.5317 - val_mae: 0.5968
# Epoch 150/150
# 5/5 [==============================] - 0s 9ms/step - loss: 0.0055 - mae: 0.0595 - val_loss: 0.5328 - val_mae: 0.6052

# %%
#onehot_df_test_encoded, H_test_encoded = prepare_test_data(onehot_df_test, H_test)  # You need to ensure that your test data is prepared in the same way as your training data
test_data = np.concatenate((onehot_df_test_encoded, H_test_encoded), axis = 1)
# Now you can make predictions on your test set
predictions = model.predict([test_data, test_data])
# Out:
# 35/35 [==============================] - 0s 765us/step

# %%
mse = mean_squared_error(y_test, predictions)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_test, predictions)
r2 = r2_score(y_test, predictions)

print('Mean Squared Error (MSE): ', mse)
print('Root Mean Squared Error (RMSE): ', rmse)
print('Mean Absolute Error (MAE): ', mae)
print('R-squared Score (R^2): ', r2)
# Out:
# Mean Squared Error (MSE):  9.084454214036622
# Root Mean Squared Error (RMSE):  3.014042835468106
# Mean Absolute Error (MAE):  1.889798867427509
# R-squared Score (R^2):  0.5595432998858644

# %%
import matplotlib.pyplot as plt

# plot predicted vs real values
plt.figure(figsize=(10, 5))
plt.plot(y_test, label='Real')
plt.plot(predictions, label='Predicted')
plt.legend()
plt.show()

# %%
differences = predictions.flatten() - y_test.flatten() # This will give the difference between your predictions and the actual values

#Create a figure with two subplots: a histogram of the differences and a scatter plot of predicted vs real values
fig, axs = plt.subplots(nrows=2, figsize=(10, 15))

#Plot histogram
axs[0].hist(differences, bins=20, density=True)
axs[0].set_title('Histogram of differences between predicted and actual values')
axs[0].set_xlabel('Differences')
axs[0].set_ylabel('Density')

#Plot scatter
axs[1].scatter(y_test, predictions, alpha=0.5)
axs[1].set_title('Scatter plot of predicted vs actual values')
axs[1].set_xlabel('Actual Values')
axs[1].set_ylabel('Predicted Values')

#Draw a diagonal line on the scatterplot
lims = [np.min([axs[1].get_xlim(), axs[1].get_ylim()]), # min of both axes
np.max([axs[1].get_xlim(), axs[1].get_ylim()])] # max of both axes
axs[1].plot(lims, lims, 'k-', alpha=0.75, zorder=0)
axs[1].set_xlim(lims)
axs[1].set_ylim(lims)

plt.tight_layout()
plt.show()
